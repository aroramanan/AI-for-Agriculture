# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/Users/apple/Desktop/Desktop/SHC_Punjab_Amritsar_Ajnala_Basic.csv')

# %%
pd.set_option('display.max_columns', 500)
data.head(5)
# Out:
#                 SampleNo  LandArea(Acre)  Longitude   Latitude    pH  \
# 0  PB/2017-18/95349546/2             3.0  31.862822  74.630238  8.26
# 1  PB/2017-18/95349546/1             3.0  31.862822  74.630238  8.26
# 2  PB/2017-18/95349583/2             3.0  31.861021  74.630262  7.77
# 3  PB/2017-18/95349583/1             3.0  31.861021  74.630262  7.77
# 4  PB/2017-18/95349622/1             5.0  31.857921  74.630546  8.24
#
#    EC (ds/m)  Organic Carbon (% L)  Phosphorus (kg/ha) Phosphorus Label  \
# 0       0.13                  0.46               29.16                M
# 1       0.13                  0.46               29.16                M
# 2       0.13                  0.39               25.24                M
# 3       0.13                  0.39               25.24                M
# 4       0.12                  0.43               39.98                M
#
#    Potassium (kh/ha) Potessium Label  Sulphur (ppm) Sulphur label  Zinc(ppm)  \
# 0             144.19               L           8.46             D       1.04
# 1             144.19               L           8.46             D       1.04
# 2             235.65               M          21.14             S       0.76
# 3             235.65               M          21.14             S       0.76
# 4             182.16               M          16.82             S       0.82
#
#   Zinc Label  Iron(ppm) Iron Label  Manganese (ppm) Maganese Label  \
# 0          S      23.72          S             2.06              S
# 1          S      23.72          S             2.06              S
# 2          S       9.97          S             2.19              S
# 3          S       9.97          S             2.19              S
# 4          S      24.83          S             2.63              S
#
#    Copper(ppm) copper Label
# 0         1.76            S
# 1         1.76            S
# 2         1.58            S
# 3         1.58            S
# 4         1.70            S

# %%
df1 = pd.read_csv('/Users/apple/Desktop/Documents/DataX-AgriAI-master/SHC_Data/SHC_Punjab_Amritsar_Ajnala_Recomendations.csv')

# %%
data.head(5)
# Out:
#                 SampleNo  LandArea(Acre)  Longitude   Latitude    pH  \
# 0  PB/2017-18/95349546/2             3.0  31.862822  74.630238  8.26
# 1  PB/2017-18/95349546/1             3.0  31.862822  74.630238  8.26
# 2  PB/2017-18/95349583/2             3.0  31.861021  74.630262  7.77
# 3  PB/2017-18/95349583/1             3.0  31.861021  74.630262  7.77
# 4  PB/2017-18/95349622/1             5.0  31.857921  74.630546  8.24
#
#    EC (ds/m)  Organic Carbon (% L)  Phosphorus (kg/ha) Phosphorus Label  \
# 0       0.13                  0.46               29.16                M
# 1       0.13                  0.46               29.16                M
# 2       0.13                  0.39               25.24                M
# 3       0.13                  0.39               25.24                M
# 4       0.12                  0.43               39.98                M
#
#    Potassium (kh/ha) Potessium Label  Sulphur (ppm) Sulphur label  Zinc(ppm)  \
# 0             144.19               L           8.46             D       1.04
# 1             144.19               L           8.46             D       1.04
# 2             235.65               M          21.14             S       0.76
# 3             235.65               M          21.14             S       0.76
# 4             182.16               M          16.82             S       0.82
#
#   Zinc Label  Iron(ppm) Iron Label  Manganese (ppm) Maganese Label  \
# 0          S      23.72          S             2.06              S
# 1          S      23.72          S             2.06              S
# 2          S       9.97          S             2.19              S
# 3          S       9.97          S             2.19              S
# 4          S      24.83          S             2.63              S
#
#    Copper(ppm) copper Label
# 0         1.76            S
# 1         1.76            S
# 2         1.58            S
# 3         1.58            S
# 4         1.70            S

# %%
dfinal = data.merge(df1, on="SampleNo", how = 'inner')

# %%
dfinal.head(5)
# Out:
#                 SampleNo  LandArea(Acre)  Longitude   Latitude    pH  \
# 0  PB/2017-18/95349546/2             3.0  31.862822  74.630238  8.26
# 1  PB/2017-18/95349546/1             3.0  31.862822  74.630238  8.26
# 2  PB/2017-18/95349793/2             3.0  31.850423  74.630354  7.96
# 3  PB/2017-18/95349793/2             3.0  31.850423  74.630354  7.96
# 4  PB/2017-18/95349793/1             3.0  31.850423  74.630354  7.96
#
#    EC (ds/m)  Organic Carbon (% L)  Phosphorus (kg/ha) Phosphorus Label  \
# 0       0.13                  0.46               29.16                M
# 1       0.13                  0.46               29.16                M
# 2       0.22                  0.46               24.39                M
# 3       0.22                  0.46               24.39                M
# 4       0.22                  0.46               24.39                M
#
#    Potassium (kh/ha) Potessium Label  Sulphur (ppm) Sulphur label  Zinc(ppm)  \
# 0             144.19               L           8.46             D       1.04
# 1             144.19               L           8.46             D       1.04
# 2             683.87          Very H          24.16             S       0.33
# 3             683.87          Very H          24.16             S       0.33
# 4             683.87          Very H          24.16             S       0.33
#
#   Zinc Label  Iron(ppm) Iron Label  Manganese (ppm) Maganese Label  \
# 0          S      23.72          S             2.06              S
# 1          S      23.72          S             2.06              S
# 2          D      11.18          S             1.46              D
# 3          D      11.18          S             1.46              D
# 4          D      11.18          S             1.46              D
#
#    Copper(ppm) copper Label      Parameters  \
# 0         1.76            S     Sulphur (S)
# 1         1.76            S     Sulphur (S)
# 2         1.70            S  Manganese (Mn)
# 3         1.70            S       Zinc (Zn)
# 4         1.70            S  Manganese (Mn)
#
#    Fertilizer_Recommendations_ThroughSoil  \
# 0  S @ 20-40 kg/ha (Gypsum 140-280 kg/ha)
# 1  S @ 20-40 kg/ha (Gypsum 140-280 kg/ha)
# 2      Manganese sulphate (10 -25 kg/ha)
# 3            Zinc sulphate (15 -25 kg/ha)
# 4      Manganese sulphate (10 -25 kg/ha)
#
#              Fertilizer_Recommendations_ThroughSpray
# 0                                                  -
# 1                                                  -
# 2  1 % Manganese sulphate + 0.25% lime or 0.5% Ma...
# 3                     0.5% Zinc sulphate +0.25% lime
# 4  1 % Manganese sulphate + 0.25% lime or 0.5% Ma...

# %%
dfinal.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-d6bfc6e5d40b> in <module>
# ----> 1 dfinal.shape()
#
# TypeError: 'tuple' object is not callable

# %%
dfinal = dfinal.drop(['Latitude','Longitude','LandArea(Acre)','SampleNo','Parameters','Maganese Label','Zinc Label','Iron Label','copper Label'],axis=1)

# %%
dfinal.tail(5)
# Out:
#         pH  EC (ds/m)  Organic Carbon (% L)  Phosphorus (kg/ha)  \
# 1284  7.22       0.34                  0.42               20.03
# 1285  7.22       0.34                  0.42               20.03
# 1286  7.22       0.34                  0.42               20.03
# 1287  7.39       0.25                  0.42               16.20
# 1288  7.39       0.25                  0.42               16.20
#
#      Phosphorus Label  Potassium (kh/ha) Potessium Label  Sulphur (ppm)  \
# 1284                L             176.42               M          26.62
# 1285                L             176.42               M          26.62
# 1286                L             176.42               M          26.62
# 1287                L             226.69               M          27.32
# 1288                L             226.69               M          27.32
#
#      Sulphur label  Zinc(ppm)  Iron(ppm)  Manganese (ppm)  Copper(ppm)  \
# 1284             S       0.95       3.62             1.70         1.65
# 1285             S       0.95       3.62             1.70         1.65
# 1286             S       0.95       3.62             1.70         1.65
# 1287             S       0.98      11.58             1.62         1.37
# 1288             S       0.98      11.58             1.62         1.37
#
#                  Fertilizer_Recommendations_ThroughSoil  \
# 1284                 Manganese sulphate (10 -25 kg/ha)
# 1285  Ferrous sulphate (25-50 kg/ha) (Soil applicati...
# 1286                 Manganese sulphate (10 -25 kg/ha)
# 1287                 Manganese sulphate (10 -25 kg/ha)
# 1288                 Manganese sulphate (10 -25 kg/ha)
#
#                 Fertilizer_Recommendations_ThroughSpray
# 1284  1 % Manganese sulphate + 0.25% lime or 0.5% Ma...
# 1285   1%  Ferrous sulphate (Spray thrice)+ 0.5 % lime
# 1286  1 % Manganese sulphate + 0.25% lime or 0.5% Ma...
# 1287  1 % Manganese sulphate + 0.25% lime or 0.5% Ma...
# 1288  1 % Manganese sulphate + 0.25% lime or 0.5% Ma...

# %%
dfinal = dfinal.drop(['Phosphorus Label','Potessium Label','Sulphur label'],axis=1)

# %%
dfinal.head(5)
# Out:
#      pH  EC (ds/m)  Organic Carbon (% L)  Phosphorus (kg/ha)  \
# 0  8.26       0.13                  0.46               29.16
# 1  8.26       0.13                  0.46               29.16
# 2  7.96       0.22                  0.46               24.39
# 3  7.96       0.22                  0.46               24.39
# 4  7.96       0.22                  0.46               24.39
#
#    Potassium (kh/ha)  Sulphur (ppm)  Zinc(ppm)  Iron(ppm)  Manganese (ppm)  \
# 0             144.19           8.46       1.04      23.72             2.06
# 1             144.19           8.46       1.04      23.72             2.06
# 2             683.87          24.16       0.33      11.18             1.46
# 3             683.87          24.16       0.33      11.18             1.46
# 4             683.87          24.16       0.33      11.18             1.46
#
#    Copper(ppm)  Fertilizer_Recommendations_ThroughSoil  \
# 0         1.76  S @ 20-40 kg/ha (Gypsum 140-280 kg/ha)
# 1         1.76  S @ 20-40 kg/ha (Gypsum 140-280 kg/ha)
# 2         1.70      Manganese sulphate (10 -25 kg/ha)
# 3         1.70            Zinc sulphate (15 -25 kg/ha)
# 4         1.70      Manganese sulphate (10 -25 kg/ha)
#
#              Fertilizer_Recommendations_ThroughSpray
# 0                                                  -
# 1                                                  -
# 2  1 % Manganese sulphate + 0.25% lime or 0.5% Ma...
# 3                     0.5% Zinc sulphate +0.25% lime
# 4  1 % Manganese sulphate + 0.25% lime or 0.5% Ma...

# %%
dfinal.describe()
# Out:
#                 pH    EC (ds/m)  Organic Carbon (% L)  Phosphorus (kg/ha)  \
# count  1289.000000  1289.000000           1289.000000         1289.000000
# mean      7.945167     0.308999              0.411435           16.102289
# std       0.440199     0.183372              0.051680            9.316000
# min       7.080000     0.100000              0.290000            2.370000
# 25%       7.550000     0.200000              0.370000            8.030000
# 50%       8.060000     0.260000              0.420000           15.610000
# 75%       8.290000     0.350000              0.450000           20.490000
# max       8.920000     0.980000              0.570000           62.070000
#
#        Potassium (kh/ha)  Sulphur (ppm)    Zinc(ppm)    Iron(ppm)  \
# count        1289.000000    1289.000000  1289.000000  1289.000000
# mean          191.267758      28.483320     0.961590     9.585687
# std           131.313244      21.281204     0.660625     4.570412
# min            31.010000       6.240000     0.200000     1.570000
# 25%            97.370000      15.330000     0.500000     6.430000
# 50%           156.730000      21.800000     0.750000     9.070000
# 75%           250.210000      35.000000     1.240000    11.610000
# max           894.430000     169.200000     5.310000    35.810000
#
#        Manganese (ppm)  Copper(ppm)
# count      1289.000000  1289.000000
# mean          1.188891     1.649829
# std           0.609858     0.719284
# min           0.110000     0.290000
# 25%           0.800000     1.120000
# 50%           1.200000     1.570000
# 75%           1.530000     2.020000
# max           4.930000     4.230000

# %%
df3 = dfinal.groupby(['EC (ds/m)','pH','Organic Carbon (% L)', 'Phosphorus (kg/ha)', 'Potassium (kh/ha)', 
       'Sulphur (ppm)',  'Zinc(ppm)', 
       'Iron(ppm)',  'Manganese (ppm)',
       'Copper(ppm)']).agg(lambda x:x.index[0])
df3.count()
# Out:
# Fertilizer_Recommendations_ThroughSoil     530
# Fertilizer_Recommendations_ThroughSpray    530
# dtype: int64

# %%
df3.head()
# Out:
#                                                                                                                                         Fertilizer_Recommendations_ThroughSoil  \
# EC (ds/m) pH   Organic Carbon (% L) Phosphorus (kg/ha) Potassium (kh/ha) Sulphur (ppm) Zinc(ppm) Iron(ppm) Manganese (ppm) Copper(ppm)
# 0.10      8.19 0.39                 21.92              119.10            21.10         1.23      22.76     1.72            1.41                                            293
#           8.30 0.50                 13.99              84.12             39.38         2.45      7.40      0.21            1.40                                            856
#           8.32 0.42                 8.00               69.87             39.89         0.48      6.10      0.49            0.79                                            814
#           8.55 0.37                 23.54              210.54            143.80        2.39      12.64     0.82            1.76                                            663
# 0.11      7.31 0.38                 7.47               93.38             26.05         1.30      13.97     1.06            2.49                                           1188
#
#                                                                                                                                         Fertilizer_Recommendations_ThroughSpray
# EC (ds/m) pH   Organic Carbon (% L) Phosphorus (kg/ha) Potassium (kh/ha) Sulphur (ppm) Zinc(ppm) Iron(ppm) Manganese (ppm) Copper(ppm)
# 0.10      8.19 0.39                 21.92              119.10            21.10         1.23      22.76     1.72            1.41                                             293
#           8.30 0.50                 13.99              84.12             39.38         2.45      7.40      0.21            1.40                                             856
#           8.32 0.42                 8.00               69.87             39.89         0.48      6.10      0.49            0.79                                             814
#           8.55 0.37                 23.54              210.54            143.80        2.39      12.64     0.82            1.76                                             663
# 0.11      7.31 0.38                 7.47               93.38             26.05         1.30      13.97     1.06            2.49                                            1188

# %%
df3.drop_duplicates(subset=None, keep='first', inplace=False)
# Out:
#                                                                                                                                         Fertilizer_Recommendations_ThroughSoil  \
# EC (ds/m) pH   Organic Carbon (% L) Phosphorus (kg/ha) Potassium (kh/ha) Sulphur (ppm) Zinc(ppm) Iron(ppm) Manganese (ppm) Copper(ppm)
# 0.10      8.19 0.39                 21.92              119.10            21.10         1.23      22.76     1.72            1.41                                            293
#           8.30 0.50                 13.99              84.12             39.38         2.45      7.40      0.21            1.40                                            856
#           8.32 0.42                 8.00               69.87             39.89         0.48      6.10      0.49            0.79                                            814
#           8.55 0.37                 23.54              210.54            143.80        2.39      12.64     0.82            1.76                                            663
# 0.11      7.31 0.38                 7.47               93.38             26.05         1.30      13.97     1.06            2.49                                           1188
# ...                                                                                                                                                                        ...
# 0.96      8.22 0.43                 7.44               66.70             39.26         0.93      4.40      0.85            0.76                                            798
# 0.97      8.28 0.46                 22.98              86.63             24.30         1.76      7.90      0.94            1.18                                            852
# 0.98      8.32 0.41                 8.99               104.80            28.99         1.16      5.03      1.35            1.63                                            808
#           8.37 0.36                 8.48               107.10            36.77         0.98      5.14      1.37            1.67                                            810
#           8.65 0.44                 6.42               66.54             45.89         1.06      7.56      0.20            1.10                                            689
#
#                                                                                                                                         Fertilizer_Recommendations_ThroughSpray
# EC (ds/m) pH   Organic Carbon (% L) Phosphorus (kg/ha) Potassium (kh/ha) Sulphur (ppm) Zinc(ppm) Iron(ppm) Manganese (ppm) Copper(ppm)
# 0.10      8.19 0.39                 21.92              119.10            21.10         1.23      22.76     1.72            1.41                                             293
#           8.30 0.50                 13.99              84.12             39.38         2.45      7.40      0.21            1.40                                             856
#           8.32 0.42                 8.00               69.87             39.89         0.48      6.10      0.49            0.79                                             814
#           8.55 0.37                 23.54              210.54            143.80        2.39      12.64     0.82            1.76                                             663
# 0.11      7.31 0.38                 7.47               93.38             26.05         1.30      13.97     1.06            2.49                                            1188
# ...                                                                                                                                                                         ...
# 0.96      8.22 0.43                 7.44               66.70             39.26         0.93      4.40      0.85            0.76                                             798
# 0.97      8.28 0.46                 22.98              86.63             24.30         1.76      7.90      0.94            1.18                                             852
# 0.98      8.32 0.41                 8.99               104.80            28.99         1.16      5.03      1.35            1.63                                             808
#           8.37 0.36                 8.48               107.10            36.77         0.98      5.14      1.37            1.67                                             810
#           8.65 0.44                 6.42               66.54             45.89         1.06      7.56      0.20            1.10                                             689
#
# [530 rows x 2 columns]

# %%
df3.count()
# Out:
# Fertilizer_Recommendations_ThroughSoil     530
# Fertilizer_Recommendations_ThroughSpray    530
# dtype: int64

# %%
dfinal.reset_index()
# Out:
#       index    pH  EC (ds/m)  Organic Carbon (% L)  Phosphorus (kg/ha)  \
# 0         0  8.26       0.13                  0.46               29.16
# 1         1  8.26       0.13                  0.46               29.16
# 2         2  7.96       0.22                  0.46               24.39
# 3         3  7.96       0.22                  0.46               24.39
# 4         4  7.96       0.22                  0.46               24.39
# ...     ...   ...        ...                   ...                 ...
# 1284   1284  7.22       0.34                  0.42               20.03
# 1285   1285  7.22       0.34                  0.42               20.03
# 1286   1286  7.22       0.34                  0.42               20.03
# 1287   1287  7.39       0.25                  0.42               16.20
# 1288   1288  7.39       0.25                  0.42               16.20
#
#       Potassium (kh/ha)  Sulphur (ppm)  Zinc(ppm)  Iron(ppm)  Manganese (ppm)  \
# 0                144.19           8.46       1.04      23.72             2.06
# 1                144.19           8.46       1.04      23.72             2.06
# 2                683.87          24.16       0.33      11.18             1.46
# 3                683.87          24.16       0.33      11.18             1.46
# 4                683.87          24.16       0.33      11.18             1.46
# ...                 ...            ...        ...        ...              ...
# 1284             176.42          26.62       0.95       3.62             1.70
# 1285             176.42          26.62       0.95       3.62             1.70
# 1286             176.42          26.62       0.95       3.62             1.70
# 1287             226.69          27.32       0.98      11.58             1.62
# 1288             226.69          27.32       0.98      11.58             1.62
#
#       Copper(ppm)             Fertilizer_Recommendations_ThroughSoil  \
# 0            1.76             S @ 20-40 kg/ha (Gypsum 140-280 kg/ha)
# 1            1.76             S @ 20-40 kg/ha (Gypsum 140-280 kg/ha)
# 2            1.70                 Manganese sulphate (10 -25 kg/ha)
# 3            1.70                       Zinc sulphate (15 -25 kg/ha)
# 4            1.70                 Manganese sulphate (10 -25 kg/ha)
# ...           ...                                                ...
# 1284         1.65                 Manganese sulphate (10 -25 kg/ha)
# 1285         1.65  Ferrous sulphate (25-50 kg/ha) (Soil applicati...
# 1286         1.65                 Manganese sulphate (10 -25 kg/ha)
# 1287         1.37                 Manganese sulphate (10 -25 kg/ha)
# 1288         1.37                 Manganese sulphate (10 -25 kg/ha)
#
#                 Fertilizer_Recommendations_ThroughSpray
# 0                                                     -
# 1                                                     -
# 2     1 % Manganese sulphate + 0.25% lime or 0.5% Ma...
# 3                        0.5% Zinc sulphate +0.25% lime
# 4     1 % Manganese sulphate + 0.25% lime or 0.5% Ma...
# ...                                                 ...
# 1284  1 % Manganese sulphate + 0.25% lime or 0.5% Ma...
# 1285   1%  Ferrous sulphate (Spray thrice)+ 0.5 % lime
# 1286  1 % Manganese sulphate + 0.25% lime or 0.5% Ma...
# 1287  1 % Manganese sulphate + 0.25% lime or 0.5% Ma...
# 1288  1 % Manganese sulphate + 0.25% lime or 0.5% Ma...
#
# [1289 rows x 13 columns]

# %%
dfinal.drop_duplicates(keep=False,inplace=True)

# %%
dfinal.reset_index()
# Out:
#      index    pH  EC (ds/m)  Organic Carbon (% L)  Phosphorus (kg/ha)  \
# 0       49  8.47       0.15                  0.38               15.82
# 1       50  8.32       0.20                  0.42               22.33
# 2       94  7.21       0.16                  0.44               12.99
# 3       95  7.21       0.16                  0.44               12.99
# 4      123  7.88       0.25                  0.44               25.85
# ..     ...   ...        ...                   ...                 ...
# 211   1241  8.92       0.24                  0.33                8.36
# 212   1242  8.52       0.30                  0.42                7.82
# 213   1258  8.53       0.39                  0.36                7.82
# 214   1261  8.29       0.38                  0.34                8.91
# 215   1272  8.24       0.24                  0.30                5.95
#
#      Potassium (kh/ha)  Sulphur (ppm)  Zinc(ppm)  Iron(ppm)  Manganese (ppm)  \
# 0               237.66          27.35       1.20       9.59             1.39
# 1               186.28          24.75       0.92      14.87             1.91
# 2               171.56          15.04       0.28      18.03             0.55
# 3               171.56          15.04       0.28      18.03             0.55
# 4               153.93          24.18       0.81      13.32             1.32
# ..                 ...            ...        ...        ...              ...
# 211             112.80          39.68       1.14      11.11             1.00
# 212              98.44          40.26       1.41      10.70             0.80
# 213             105.10          55.39       1.71      11.10             1.51
# 214             119.30          24.05       1.95      15.69             0.89
# 215              88.88          31.17       1.20      13.87             1.02
#
#      Copper(ppm) Fertilizer_Recommendations_ThroughSoil  \
# 0           2.13     Manganese sulphate (10 -25 kg/ha)
# 1           1.88     Manganese sulphate (10 -25 kg/ha)
# 2           1.68     Manganese sulphate (10 -25 kg/ha)
# 3           1.68           Zinc sulphate (15 -25 kg/ha)
# 4           1.82     Manganese sulphate (10 -25 kg/ha)
# ..           ...                                    ...
# 211         1.97     Manganese sulphate (10 -25 kg/ha)
# 212         1.78     Manganese sulphate (10 -25 kg/ha)
# 213         1.97     Manganese sulphate (10 -25 kg/ha)
# 214         2.41     Manganese sulphate (10 -25 kg/ha)
# 215         1.80     Manganese sulphate (10 -25 kg/ha)
#
#                Fertilizer_Recommendations_ThroughSpray
# 0    1 % Manganese sulphate + 0.25% lime or 0.5% Ma...
# 1    1 % Manganese sulphate + 0.25% lime or 0.5% Ma...
# 2    1 % Manganese sulphate + 0.25% lime or 0.5% Ma...
# 3                       0.5% Zinc sulphate +0.25% lime
# 4    1 % Manganese sulphate + 0.25% lime or 0.5% Ma...
# ..                                                 ...
# 211  1 % Manganese sulphate + 0.25% lime or 0.5% Ma...
# 212  1 % Manganese sulphate + 0.25% lime or 0.5% Ma...
# 213  1 % Manganese sulphate + 0.25% lime or 0.5% Ma...
# 214  1 % Manganese sulphate + 0.25% lime or 0.5% Ma...
# 215  1 % Manganese sulphate + 0.25% lime or 0.5% Ma...
#
# [216 rows x 13 columns]

# %%
dfinal.head(5)
# Out:
#        pH  EC (ds/m)  Organic Carbon (% L)  Phosphorus (kg/ha)  \
# 49   8.47       0.15                  0.38               15.82
# 50   8.32       0.20                  0.42               22.33
# 94   7.21       0.16                  0.44               12.99
# 95   7.21       0.16                  0.44               12.99
# 123  7.88       0.25                  0.44               25.85
#
#      Potassium (kh/ha)  Sulphur (ppm)  Zinc(ppm)  Iron(ppm)  Manganese (ppm)  \
# 49              237.66          27.35       1.20       9.59             1.39
# 50              186.28          24.75       0.92      14.87             1.91
# 94              171.56          15.04       0.28      18.03             0.55
# 95              171.56          15.04       0.28      18.03             0.55
# 123             153.93          24.18       0.81      13.32             1.32
#
#      Copper(ppm) Fertilizer_Recommendations_ThroughSoil  \
# 49          2.13     Manganese sulphate (10 -25 kg/ha)
# 50          1.88     Manganese sulphate (10 -25 kg/ha)
# 94          1.68     Manganese sulphate (10 -25 kg/ha)
# 95          1.68           Zinc sulphate (15 -25 kg/ha)
# 123         1.82     Manganese sulphate (10 -25 kg/ha)
#
#                Fertilizer_Recommendations_ThroughSpray
# 49   1 % Manganese sulphate + 0.25% lime or 0.5% Ma...
# 50   1 % Manganese sulphate + 0.25% lime or 0.5% Ma...
# 94   1 % Manganese sulphate + 0.25% lime or 0.5% Ma...
# 95                      0.5% Zinc sulphate +0.25% lime
# 123  1 % Manganese sulphate + 0.25% lime or 0.5% Ma...

# %%
dfinal1 = dfinal.drop_duplicates()
