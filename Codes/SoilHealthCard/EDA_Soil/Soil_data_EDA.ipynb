# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy import stats

# %%
data = pd.read_csv('/Users/apple/Desktop/Desktop/SHC_Punjab_Amritsar_Ajnala_Basic.csv')
df1 = pd.read_csv('/Users/apple/Desktop/Documents/DataX-AgriAI-master/SHC_Data/SHC_Punjab_Amritsar_Ajnala_Recomendations.csv')
df2 = pd.read_csv('/Users/apple/Desktop/Documents/DataX-AgriAI-master/SHC_Data/SHC_Punjab_Amritsar_Ajnala_Fertilizers.csv')

# %%
data.head()
# Out:
#                 SampleNo  LandArea(Acre)  Longitude   Latitude    pH  \
# 0  PB/2017-18/95349546/2             3.0  31.862822  74.630238  8.26
# 1  PB/2017-18/95349546/1             3.0  31.862822  74.630238  8.26
# 2  PB/2017-18/95349583/2             3.0  31.861021  74.630262  7.77
# 3  PB/2017-18/95349583/1             3.0  31.861021  74.630262  7.77
# 4  PB/2017-18/95349622/1             5.0  31.857921  74.630546  8.24
#
#    EC (ds/m)  Organic Carbon (% L)  Phosphorus (kg/ha) Phosphorus Label  \
# 0       0.13                  0.46               29.16                M
# 1       0.13                  0.46               29.16                M
# 2       0.13                  0.39               25.24                M
# 3       0.13                  0.39               25.24                M
# 4       0.12                  0.43               39.98                M
#
#    Potassium (kh/ha)  ... Sulphur (ppm)  Sulphur label Zinc(ppm)  Zinc Label  \
# 0             144.19  ...          8.46              D      1.04           S
# 1             144.19  ...          8.46              D      1.04           S
# 2             235.65  ...         21.14              S      0.76           S
# 3             235.65  ...         21.14              S      0.76           S
# 4             182.16  ...         16.82              S      0.82           S
#
#   Iron(ppm)  Iron Label Manganese (ppm)  Maganese Label Copper(ppm)  \
# 0     23.72           S            2.06               S        1.76
# 1     23.72           S            2.06               S        1.76
# 2      9.97           S            2.19               S        1.58
# 3      9.97           S            2.19               S        1.58
# 4     24.83           S            2.63               S        1.70
#
#    copper Label
# 0             S
# 1             S
# 2             S
# 3             S
# 4             S
#
# [5 rows x 21 columns]

# %%
data.count()
# Out:
# SampleNo                1415
# LandArea(Acre)          1411
# Longitude               1415
# Latitude                1415
# pH                      1415
# EC (ds/m)               1415
# Organic Carbon (% L)    1415
# Phosphorus (kg/ha)      1415
# Phosphorus Label        1415
# Potassium (kh/ha)       1415
# Potessium Label         1415
# Sulphur (ppm)           1415
# Sulphur label           1415
# Zinc(ppm)               1415
# Zinc Label              1415
# Iron(ppm)               1415
# Iron Label              1415
# Manganese (ppm)         1415
# Maganese Label          1402
# Copper(ppm)             1415
# copper Label            1415
# dtype: int64

# %%
data.describe()
# Out:
#        LandArea(Acre)    Longitude     Latitude           pH    EC (ds/m)  \
# count     1411.000000  1415.000000  1415.000000  1415.000000  1415.000000
# mean         4.995677    31.791895    74.732990     7.938042     0.299548
# std          3.076096     0.125692     0.145229     0.437418     0.174358
# min          0.500000    31.293880    74.363505     7.010000     0.100000
# 25%          3.000000    31.720864    74.623861     7.560000     0.200000
# 50%          4.000000    31.789400    74.781570     8.020000     0.250000
# 75%          7.000000    31.897605    74.841410     8.270000     0.330000
# max         12.500000    31.998330    75.365745     8.920000     0.980000
#
#        Organic Carbon (% L)  Phosphorus (kg/ha)  Potassium (kh/ha)  \
# count           1415.000000         1415.000000        1415.000000
# mean               0.412855           15.539456         176.001230
# std                0.052944            9.474515         116.725398
# min                0.280000            2.370000          31.010000
# 25%                0.370000            8.200000          99.350000
# 50%                0.420000           13.180000         136.330000
# 75%                0.450000           20.070000         218.415000
# max                0.570000           62.590000         894.430000
#
#        Sulphur (ppm)    Zinc(ppm)    Iron(ppm)  Manganese (ppm)  Copper(ppm)
# count    1415.000000  1415.000000  1415.000000      1415.000000  1415.000000
# mean       29.465081     1.149329    11.752198         1.975138     1.883986
# std        19.709855     0.679078     5.268741         1.433650     0.814497
# min         6.240000     0.200000     1.570000         0.110000     0.290000
# 25%        17.290000     0.700000     7.885000         0.980000     1.355000
# 50%        24.080000     1.040000    10.890000         1.500000     1.710000
# 75%        34.710000     1.350000    14.830000         2.775000     2.250000
# max       169.200000     5.690000    35.810000         6.740000     6.040000

# %%
df1.head()
# Out:
#                  SampleNo Parameters  \
# 0   PB/2017-18/95639425/2  Iron (Fe)
# 1   PB/2017-18/95639425/1  Iron (Fe)
# 2  PB/2017-18/106910860/2  Iron (Fe)
# 3  PB/2017-18/106910860/1  Iron (Fe)
# 4  PB/2017-18/106978273/2  Iron (Fe)
#
#               Fertilizer_Recommendations_ThroughSoil  \
# 0  Ferrous sulphate (25-50 kg/ha) (Soil applicati...
# 1  Ferrous sulphate (25-50 kg/ha) (Soil applicati...
# 2  Ferrous sulphate (25-50 kg/ha) (Soil applicati...
# 3  Ferrous sulphate (25-50 kg/ha) (Soil applicati...
# 4  Ferrous sulphate (25-50 kg/ha) (Soil applicati...
#
#             Fertilizer_Recommendations_ThroughSpray
# 0  1%  Ferrous sulphate (Spray thrice)+ 0.5 % lime
# 1  1%  Ferrous sulphate (Spray thrice)+ 0.5 % lime
# 2  1%  Ferrous sulphate (Spray thrice)+ 0.5 % lime
# 3  1%  Ferrous sulphate (Spray thrice)+ 0.5 % lime
# 4  1%  Ferrous sulphate (Spray thrice)+ 0.5 % lime

# %%
df1.count()
# Out:
# SampleNo                                   1279
# Parameters                                 1279
# Fertilizer_Recommendations_ThroughSoil     1279
# Fertilizer_Recommendations_ThroughSpray    1279
# dtype: int64

# %%
df1.describe()
# Out:
#                       SampleNo      Parameters  \
# count                     1279            1279
# unique                     980               4
# top     PB/2017-18/106910860/1  Manganese (Mn)
# freq                         4             916
#
#        Fertilizer_Recommendations_ThroughSoil  \
# count                                    1279
# unique                                      4
# top        Manganese sulphate (10 -25 kg/ha)
# freq                                      916
#
#                   Fertilizer_Recommendations_ThroughSpray
# count                                                1279
# unique                                                  4
# top     1 % Manganese sulphate + 0.25% lime or 0.5% Ma...
# freq                                                  916

# %%
df2.head()
# Out:
#                 SampleNo            Crop_Name  \
# 0  PB/2017-18/95349546/2  Buck Wheat (Kaspat)
# 1  PB/2017-18/95349546/2         Paddy(Dhaan)
# 2  PB/2017-18/95349546/2                Maize
# 3  PB/2017-18/95349546/2              Mustard
# 4  PB/2017-18/95349546/2            Sugarcane
#
#                             Fertiliser_Combination_1  \
# 0  Neem Coated Urea  : 0 | Single Superphosphate ...
# 1  Neem Coated Urea  : 0 | Single Superphosphate ...
# 2  Neem Coated Urea  : 361 | Single Superphosphat...
# 3  Neem Coated Urea  : 289 | Single Superphosphat...
# 4  Neem Coated Urea  : 0 | Single Superphosphate ...
#
#                             Fertiliser_Combination_2
# 0  Diammonium Phosphate (18-46-0): 0 | Neem Coate...
# 1  Diammonium Phosphate (18-46-0): 0 | Neem Coate...
# 2  Diammonium Phosphate (18-46-0): 130 | Neem Coa...
# 3  Diammonium Phosphate (18-46-0): 65 | Neem Coat...
# 4  Diammonium Phosphate (18-46-0): 0 | Neem Coate...

# %%
df2.count()
# Out:
# SampleNo                    6546
# Crop_Name                   6546
# Fertiliser_Combination_1    6546
# Fertiliser_Combination_2    6546
# dtype: int64

# %%
df2.describe()
# Out:
#                      SampleNo     Crop_Name  \
# count                    6546          6546
# unique                   1410             7
# top     PB/2017-18/95522227/1  Paddy(Dhaan)
# freq                       12          1415
#
#                                  Fertiliser_Combination_1  \
# count                                                6546
# unique                                                 80
# top     Neem Coated Urea  : 0 | Single Superphosphate ...
# freq                                                 2769
#
#                                  Fertiliser_Combination_2
# count                                                6546
# unique                                                 84
# top     Diammonium Phosphate (18-46-0): 0 | Neem Coate...
# freq                                                 2769

# %%
dfinal = df1.merge(df2, on="SampleNo", how = 'inner')

# %%
dfinal.head(5)
#dfinal.describe()
# Out:
#                 SampleNo Parameters  \
# 0  PB/2017-18/95639425/2  Iron (Fe)
# 1  PB/2017-18/95639425/2  Iron (Fe)
# 2  PB/2017-18/95639425/2  Iron (Fe)
# 3  PB/2017-18/95639425/2  Iron (Fe)
# 4  PB/2017-18/95639425/2  Iron (Fe)
#
#               Fertilizer_Recommendations_ThroughSoil  \
# 0  Ferrous sulphate (25-50 kg/ha) (Soil applicati...
# 1  Ferrous sulphate (25-50 kg/ha) (Soil applicati...
# 2  Ferrous sulphate (25-50 kg/ha) (Soil applicati...
# 3  Ferrous sulphate (25-50 kg/ha) (Soil applicati...
# 4  Ferrous sulphate (25-50 kg/ha) (Soil applicati...
#
#             Fertilizer_Recommendations_ThroughSpray            Crop_Name  \
# 0  1%  Ferrous sulphate (Spray thrice)+ 0.5 % lime   Buck Wheat (Kaspat)
# 1  1%  Ferrous sulphate (Spray thrice)+ 0.5 % lime          Paddy(Dhaan)
# 2  1%  Ferrous sulphate (Spray thrice)+ 0.5 % lime                 Maize
# 3  1%  Ferrous sulphate (Spray thrice)+ 0.5 % lime               Mustard
# 4  1%  Ferrous sulphate (Spray thrice)+ 0.5 % lime             Sugarcane
#
#                             Fertiliser_Combination_1  \
# 0  Neem Coated Urea  : 0 | Single Superphosphate ...
# 1  Neem Coated Urea  : 0 | Single Superphosphate ...
# 2  Neem Coated Urea  : 361 | Single Superphosphat...
# 3  Neem Coated Urea  : 289 | Single Superphosphat...
# 4  Neem Coated Urea  : 0 | Single Superphosphate ...
#
#                             Fertiliser_Combination_2
# 0  Diammonium Phosphate (18-46-0): 0 | Neem Coate...
# 1  Diammonium Phosphate (18-46-0): 0 | Neem Coate...
# 2  Diammonium Phosphate (18-46-0): 130 | Neem Coa...
# 3  Diammonium Phosphate (18-46-0): 65 | Neem Coat...
# 4  Diammonium Phosphate (18-46-0): 0 | Neem Coate...

# %%
dfinal.count
# Out:
# <bound method DataFrame.count of                    SampleNo   Parameters  \
# 0     PB/2017-18/95639425/2    Iron (Fe)
# 1     PB/2017-18/95639425/2    Iron (Fe)
# 2     PB/2017-18/95639425/2    Iron (Fe)
# 3     PB/2017-18/95639425/2    Iron (Fe)
# 4     PB/2017-18/95639425/2    Iron (Fe)
# ...                     ...          ...
# 5633  PB/2017-18/95451228/1  Sulphur (S)
# 5634  PB/2017-18/95451228/1  Sulphur (S)
# 5635  PB/2017-18/95451228/1  Sulphur (S)
# 5636  PB/2017-18/95451228/1  Sulphur (S)
# 5637  PB/2017-18/95451228/1  Sulphur (S)
#
#                  Fertilizer_Recommendations_ThroughSoil  \
# 0     Ferrous sulphate (25-50 kg/ha) (Soil applicati...
# 1     Ferrous sulphate (25-50 kg/ha) (Soil applicati...
# 2     Ferrous sulphate (25-50 kg/ha) (Soil applicati...
# 3     Ferrous sulphate (25-50 kg/ha) (Soil applicati...
# 4     Ferrous sulphate (25-50 kg/ha) (Soil applicati...
# ...                                                 ...
# 5633             S @ 20-40 kg/ha (Gypsum 140-280 kg/ha)
# 5634             S @ 20-40 kg/ha (Gypsum 140-280 kg/ha)
# 5635             S @ 20-40 kg/ha (Gypsum 140-280 kg/ha)
# 5636             S @ 20-40 kg/ha (Gypsum 140-280 kg/ha)
# 5637             S @ 20-40 kg/ha (Gypsum 140-280 kg/ha)
#
#                Fertilizer_Recommendations_ThroughSpray            Crop_Name  \
# 0     1%  Ferrous sulphate (Spray thrice)+ 0.5 % lime   Buck Wheat (Kaspat)
# 1     1%  Ferrous sulphate (Spray thrice)+ 0.5 % lime          Paddy(Dhaan)
# 2     1%  Ferrous sulphate (Spray thrice)+ 0.5 % lime                 Maize
# 3     1%  Ferrous sulphate (Spray thrice)+ 0.5 % lime               Mustard
# 4     1%  Ferrous sulphate (Spray thrice)+ 0.5 % lime             Sugarcane
# ...                                                ...                  ...
# 5633                                                 -         Paddy(Dhaan)
# 5634                                                 -                Maize
# 5635                                                 -              Mustard
# 5636                                                 -            Sugarcane
# 5637                                                 -               Cotton
#
#                                Fertiliser_Combination_1  \
# 0     Neem Coated Urea  : 0 | Single Superphosphate ...
# 1     Neem Coated Urea  : 0 | Single Superphosphate ...
# 2     Neem Coated Urea  : 361 | Single Superphosphat...
# 3     Neem Coated Urea  : 289 | Single Superphosphat...
# 4     Neem Coated Urea  : 0 | Single Superphosphate ...
# ...                                                 ...
# 5633  Neem Coated Urea  : 0 | Single Superphosphate ...
# 5634  Neem Coated Urea  : 272 | Single Superphosphat...
# 5635  Neem Coated Urea  : 217 | Single Superphosphat...
# 5636  Neem Coated Urea  : 0 | Single Superphosphate ...
# 5637  Neem Coated Urea  : 326 | Single Superphosphat...
#
#                                Fertiliser_Combination_2
# 0     Diammonium Phosphate (18-46-0): 0 | Neem Coate...
# 1     Diammonium Phosphate (18-46-0): 0 | Neem Coate...
# 2     Diammonium Phosphate (18-46-0): 130 | Neem Coa...
# 3     Diammonium Phosphate (18-46-0): 65 | Neem Coat...
# 4     Diammonium Phosphate (18-46-0): 0 | Neem Coate...
# ...                                                 ...
# 5633  Diammonium Phosphate (18-46-0): 0 | Neem Coate...
# 5634  Diammonium Phosphate (18-46-0): 174 | Neem Coa...
# 5635  Diammonium Phosphate (18-46-0): 87 | Neem Coat...
# 5636  Diammonium Phosphate (18-46-0): 0 | Neem Coate...
# 5637  Diammonium Phosphate (18-46-0): 87 | Neem Coat...
#
# [5638 rows x 7 columns]>

# %%
dfinal.describe()
# Out:
#                      SampleNo      Parameters  \
# count                    5638            5638
# unique                    980               4
# top     PB/2017-18/95522227/1  Manganese (Mn)
# freq                       24            3716
#
#        Fertilizer_Recommendations_ThroughSoil  \
# count                                    5638
# unique                                      4
# top        Manganese sulphate (10 -25 kg/ha)
# freq                                     3716
#
#                   Fertilizer_Recommendations_ThroughSpray     Crop_Name  \
# count                                                5638          5638
# unique                                                  4             7
# top     1 % Manganese sulphate + 0.25% lime or 0.5% Ma...  Paddy(Dhaan)
# freq                                                 3716          1289
#
#                                  Fertiliser_Combination_1  \
# count                                                5638
# unique                                                 68
# top     Neem Coated Urea  : 0 | Single Superphosphate ...
# freq                                                 2273
#
#                                  Fertiliser_Combination_2
# count                                                5638
# unique                                                 72
# top     Diammonium Phosphate (18-46-0): 0 | Neem Coate...
# freq                                                 2273

# %%
dfinal2 = data.merge(dfinal, on="SampleNo", how = 'inner')

# %%
dfinal2.describe()
# Out:
#        LandArea(Acre)    Longitude     Latitude           pH    EC (ds/m)  \
# count     5686.000000  5694.000000  5694.000000  5694.000000  5694.000000
# mean         5.261062    31.825081    74.724084     7.886259     0.281103
# std          3.691524     0.105098     0.125353     0.445228     0.147853
# min          0.500000    31.293880    74.363957     7.080000     0.100000
# 25%          2.200000    31.784610    74.632270     7.510000     0.190000
# 50%          4.000000    31.853376    74.673020     7.890000     0.250000
# 75%          7.500000    31.897570    74.838652     8.260000     0.330000
# max         12.500000    31.998330    74.989640     8.920000     0.980000
#
#        Organic Carbon (% L)  Phosphorus (kg/ha)  Potassium (kh/ha)  \
# count           5694.000000         5694.000000        5694.000000
# mean               0.418265           18.761036         225.954837
# std                0.048710            9.322687         136.245087
# min                0.290000            2.370000          31.010000
# 25%                0.390000           13.550000         126.020000
# 50%                0.420000           17.800000         204.470000
# 75%                0.450000           21.750000         270.820000
# max                0.570000           62.070000         894.430000
#
#        Sulphur (ppm)    Zinc(ppm)    Iron(ppm)  Manganese (ppm)  Copper(ppm)
# count    5694.000000  5694.000000  5694.000000      5694.000000  5694.000000
# mean       22.856312     0.862371     9.813934         1.311858     1.710091
# std        16.331625     0.640290     4.579869         0.594280     0.727065
# min         6.240000     0.200000     1.570000         0.110000     0.290000
# 25%        13.230000     0.450000     6.580000         0.930000     1.180000
# 50%        18.820000     0.610000     9.150000         1.300000     1.600000
# 75%        26.180000     1.070000    11.610000         1.590000     2.100000
# max       169.200000     5.310000    35.810000         4.930000     4.230000

# %%
dfinal2.count()
# Out:
# SampleNo                                   5694
# LandArea(Acre)                             5686
# Longitude                                  5694
# Latitude                                   5694
# pH                                         5694
# EC (ds/m)                                  5694
# Organic Carbon (% L)                       5694
# Phosphorus (kg/ha)                         5694
# Phosphorus Label                           5694
# Potassium (kh/ha)                          5694
# Potessium Label                            5694
# Sulphur (ppm)                              5694
# Sulphur label                              5694
# Zinc(ppm)                                  5694
# Zinc Label                                 5694
# Iron(ppm)                                  5694
# Iron Label                                 5694
# Manganese (ppm)                            5694
# Maganese Label                             5684
# Copper(ppm)                                5694
# copper Label                               5694
# Parameters                                 5694
# Fertilizer_Recommendations_ThroughSoil     5694
# Fertilizer_Recommendations_ThroughSpray    5694
# Crop_Name                                  5694
# Fertiliser_Combination_1                   5694
# Fertiliser_Combination_2                   5694
# dtype: int64

# %%
df3 = dfinal.groupby(['Fertiliser_Combination_1','Fertiliser_Combination_2']).agg(lambda x:x.value_counts().index[0])
# Out:
# SampleNo                                   72
# Parameters                                 72
# Fertilizer_Recommendations_ThroughSoil     72
# Fertilizer_Recommendations_ThroughSpray    72
# Crop_Name                                  72
# dtype: int64

# %%
df3.count()
# Out:
# SampleNo                                   72
# Parameters                                 72
# Fertilizer_Recommendations_ThroughSoil     72
# Fertilizer_Recommendations_ThroughSpray    72
# Crop_Name                                  72
# dtype: int64

# %%
df3.head()
# Out:
#                                                                                                                     SampleNo  \
# Fertiliser_Combination_1                           Fertiliser_Combination_2
# Neem Coated Urea  : 0 | Single Superphosphate (... Diammonium Phosphate (18-46-0): 0 | Neem Coated...  PB/2017-18/95522227/1
# Neem Coated Urea  : 217 | Single Superphosphate... Diammonium Phosphate (18-46-0): 43 | Neem Coate...  PB/2017-18/95520880/1
# Neem Coated Urea  : 217 | Single Superphosphate... Diammonium Phosphate (18-46-0): 65 | Neem Coate...  PB/2017-18/94964675/2
# Neem Coated Urea  : 217 | Single Superphosphate... Diammonium Phosphate (18-46-0): 87 | Neem Coate...  PB/2017-18/95481244/3
# Neem Coated Urea  : 217 | Single Superphosphate... Diammonium Phosphate (18-46-0): 87 | Neem Coate...  PB/2017-18/95451096/1
#
#                                                                                                            Parameters  \
# Fertiliser_Combination_1                           Fertiliser_Combination_2
# Neem Coated Urea  : 0 | Single Superphosphate (... Diammonium Phosphate (18-46-0): 0 | Neem Coated...  Manganese (Mn)
# Neem Coated Urea  : 217 | Single Superphosphate... Diammonium Phosphate (18-46-0): 43 | Neem Coate...  Manganese (Mn)
# Neem Coated Urea  : 217 | Single Superphosphate... Diammonium Phosphate (18-46-0): 65 | Neem Coate...       Zinc (Zn)
# Neem Coated Urea  : 217 | Single Superphosphate... Diammonium Phosphate (18-46-0): 87 | Neem Coate...       Zinc (Zn)
# Neem Coated Urea  : 217 | Single Superphosphate... Diammonium Phosphate (18-46-0): 87 | Neem Coate...       Zinc (Zn)
#
#                                                                                                       Fertilizer_Recommendations_ThroughSoil  \
# Fertiliser_Combination_1                           Fertiliser_Combination_2
# Neem Coated Urea  : 0 | Single Superphosphate (... Diammonium Phosphate (18-46-0): 0 | Neem Coated...     Manganese sulphate (10 -25 kg/ha)
# Neem Coated Urea  : 217 | Single Superphosphate... Diammonium Phosphate (18-46-0): 43 | Neem Coate...     Manganese sulphate (10 -25 kg/ha)
# Neem Coated Urea  : 217 | Single Superphosphate... Diammonium Phosphate (18-46-0): 65 | Neem Coate...     Manganese sulphate (10 -25 kg/ha)
# Neem Coated Urea  : 217 | Single Superphosphate... Diammonium Phosphate (18-46-0): 87 | Neem Coate...           Zinc sulphate (15 -25 kg/ha)
# Neem Coated Urea  : 217 | Single Superphosphate... Diammonium Phosphate (18-46-0): 87 | Neem Coate...           Zinc sulphate (15 -25 kg/ha)
#
#                                                                                                                  Fertilizer_Recommendations_ThroughSpray  \
# Fertiliser_Combination_1                           Fertiliser_Combination_2
# Neem Coated Urea  : 0 | Single Superphosphate (... Diammonium Phosphate (18-46-0): 0 | Neem Coated...  1 % Manganese sulphate + 0.25% lime or 0.5% Ma...
# Neem Coated Urea  : 217 | Single Superphosphate... Diammonium Phosphate (18-46-0): 43 | Neem Coate...  1 % Manganese sulphate + 0.25% lime or 0.5% Ma...
# Neem Coated Urea  : 217 | Single Superphosphate... Diammonium Phosphate (18-46-0): 65 | Neem Coate...  1 % Manganese sulphate + 0.25% lime or 0.5% Ma...
# Neem Coated Urea  : 217 | Single Superphosphate... Diammonium Phosphate (18-46-0): 87 | Neem Coate...                     0.5% Zinc sulphate +0.25% lime
# Neem Coated Urea  : 217 | Single Superphosphate... Diammonium Phosphate (18-46-0): 87 | Neem Coate...                     0.5% Zinc sulphate +0.25% lime
#
#                                                                                                                  Crop_Name
# Fertiliser_Combination_1                           Fertiliser_Combination_2
# Neem Coated Urea  : 0 | Single Superphosphate (... Diammonium Phosphate (18-46-0): 0 | Neem Coated...  Buck Wheat (Kaspat)
# Neem Coated Urea  : 217 | Single Superphosphate... Diammonium Phosphate (18-46-0): 43 | Neem Coate...              Mustard
# Neem Coated Urea  : 217 | Single Superphosphate... Diammonium Phosphate (18-46-0): 65 | Neem Coate...              Mustard
# Neem Coated Urea  : 217 | Single Superphosphate... Diammonium Phosphate (18-46-0): 87 | Neem Coate...              Mustard
# Neem Coated Urea  : 217 | Single Superphosphate... Diammonium Phosphate (18-46-0): 87 | Neem Coate...              Mustard

# %%
df3.drop_duplicates(subset=None, keep='first', inplace=False)
# Out:
#                                                                                                                     SampleNo  \
# Fertiliser_Combination_1                           Fertiliser_Combination_2
# Neem Coated Urea  : 0 | Single Superphosphate (... Diammonium Phosphate (18-46-0): 0 | Neem Coated...  PB/2017-18/95522227/1
# Neem Coated Urea  : 217 | Single Superphosphate... Diammonium Phosphate (18-46-0): 43 | Neem Coate...  PB/2017-18/95520880/1
# Neem Coated Urea  : 217 | Single Superphosphate... Diammonium Phosphate (18-46-0): 65 | Neem Coate...  PB/2017-18/94964675/2
# Neem Coated Urea  : 217 | Single Superphosphate... Diammonium Phosphate (18-46-0): 87 | Neem Coate...  PB/2017-18/95481244/3
# Neem Coated Urea  : 217 | Single Superphosphate... Diammonium Phosphate (18-46-0): 87 | Neem Coate...  PB/2017-18/95451096/1
# ...                                                                                                                      ...
# Neem Coated Urea  : 435 | Single Superphosphate... Diammonium Phosphate (18-46-0): 87 | Neem Coate...  PB/2017-18/95449801/1
# Neem Coated Urea  : 435 | Single Superphosphate... Diammonium Phosphate (18-46-0): 87 | Neem Coate...  PB/2017-18/95454106/1
# Neem Coated Urea  : 435 | Single Superphosphate... Diammonium Phosphate (18-46-0): 87 | Neem Coate...  PB/2017-18/95353614/2
# Neem Coated Urea  : 435 | Single Superphosphate... Diammonium Phosphate (18-46-0): 109 | Neem Coat...  PB/2017-18/95351560/2
# Neem Coated Urea  : 435 | Single Superphosphate... Diammonium Phosphate (18-46-0): 109 | Neem Coat...  PB/2017-18/95521629/2
#
#                                                                                                            Parameters  \
# Fertiliser_Combination_1                           Fertiliser_Combination_2
# Neem Coated Urea  : 0 | Single Superphosphate (... Diammonium Phosphate (18-46-0): 0 | Neem Coated...  Manganese (Mn)
# Neem Coated Urea  : 217 | Single Superphosphate... Diammonium Phosphate (18-46-0): 43 | Neem Coate...  Manganese (Mn)
# Neem Coated Urea  : 217 | Single Superphosphate... Diammonium Phosphate (18-46-0): 65 | Neem Coate...       Zinc (Zn)
# Neem Coated Urea  : 217 | Single Superphosphate... Diammonium Phosphate (18-46-0): 87 | Neem Coate...       Zinc (Zn)
# Neem Coated Urea  : 217 | Single Superphosphate... Diammonium Phosphate (18-46-0): 87 | Neem Coate...       Zinc (Zn)
# ...                                                                                                               ...
# Neem Coated Urea  : 435 | Single Superphosphate... Diammonium Phosphate (18-46-0): 87 | Neem Coate...  Manganese (Mn)
# Neem Coated Urea  : 435 | Single Superphosphate... Diammonium Phosphate (18-46-0): 87 | Neem Coate...  Manganese (Mn)
# Neem Coated Urea  : 435 | Single Superphosphate... Diammonium Phosphate (18-46-0): 87 | Neem Coate...  Manganese (Mn)
# Neem Coated Urea  : 435 | Single Superphosphate... Diammonium Phosphate (18-46-0): 109 | Neem Coat...  Manganese (Mn)
# Neem Coated Urea  : 435 | Single Superphosphate... Diammonium Phosphate (18-46-0): 109 | Neem Coat...  Manganese (Mn)
#
#                                                                                                       Fertilizer_Recommendations_ThroughSoil  \
# Fertiliser_Combination_1                           Fertiliser_Combination_2
# Neem Coated Urea  : 0 | Single Superphosphate (... Diammonium Phosphate (18-46-0): 0 | Neem Coated...     Manganese sulphate (10 -25 kg/ha)
# Neem Coated Urea  : 217 | Single Superphosphate... Diammonium Phosphate (18-46-0): 43 | Neem Coate...     Manganese sulphate (10 -25 kg/ha)
# Neem Coated Urea  : 217 | Single Superphosphate... Diammonium Phosphate (18-46-0): 65 | Neem Coate...     Manganese sulphate (10 -25 kg/ha)
# Neem Coated Urea  : 217 | Single Superphosphate... Diammonium Phosphate (18-46-0): 87 | Neem Coate...           Zinc sulphate (15 -25 kg/ha)
# Neem Coated Urea  : 217 | Single Superphosphate... Diammonium Phosphate (18-46-0): 87 | Neem Coate...           Zinc sulphate (15 -25 kg/ha)
# ...                                                                                                                                      ...
# Neem Coated Urea  : 435 | Single Superphosphate... Diammonium Phosphate (18-46-0): 87 | Neem Coate...     Manganese sulphate (10 -25 kg/ha)
# Neem Coated Urea  : 435 | Single Superphosphate... Diammonium Phosphate (18-46-0): 87 | Neem Coate...     Manganese sulphate (10 -25 kg/ha)
# Neem Coated Urea  : 435 | Single Superphosphate... Diammonium Phosphate (18-46-0): 87 | Neem Coate...     Manganese sulphate (10 -25 kg/ha)
# Neem Coated Urea  : 435 | Single Superphosphate... Diammonium Phosphate (18-46-0): 109 | Neem Coat...     Manganese sulphate (10 -25 kg/ha)
# Neem Coated Urea  : 435 | Single Superphosphate... Diammonium Phosphate (18-46-0): 109 | Neem Coat...     Manganese sulphate (10 -25 kg/ha)
#
#                                                                                                                  Fertilizer_Recommendations_ThroughSpray  \
# Fertiliser_Combination_1                           Fertiliser_Combination_2
# Neem Coated Urea  : 0 | Single Superphosphate (... Diammonium Phosphate (18-46-0): 0 | Neem Coated...  1 % Manganese sulphate + 0.25% lime or 0.5% Ma...
# Neem Coated Urea  : 217 | Single Superphosphate... Diammonium Phosphate (18-46-0): 43 | Neem Coate...  1 % Manganese sulphate + 0.25% lime or 0.5% Ma...
# Neem Coated Urea  : 217 | Single Superphosphate... Diammonium Phosphate (18-46-0): 65 | Neem Coate...  1 % Manganese sulphate + 0.25% lime or 0.5% Ma...
# Neem Coated Urea  : 217 | Single Superphosphate... Diammonium Phosphate (18-46-0): 87 | Neem Coate...                     0.5% Zinc sulphate +0.25% lime
# Neem Coated Urea  : 217 | Single Superphosphate... Diammonium Phosphate (18-46-0): 87 | Neem Coate...                     0.5% Zinc sulphate +0.25% lime
# ...                                                                                                                                                  ...
# Neem Coated Urea  : 435 | Single Superphosphate... Diammonium Phosphate (18-46-0): 87 | Neem Coate...  1 % Manganese sulphate + 0.25% lime or 0.5% Ma...
# Neem Coated Urea  : 435 | Single Superphosphate... Diammonium Phosphate (18-46-0): 87 | Neem Coate...  1 % Manganese sulphate + 0.25% lime or 0.5% Ma...
# Neem Coated Urea  : 435 | Single Superphosphate... Diammonium Phosphate (18-46-0): 87 | Neem Coate...  1 % Manganese sulphate + 0.25% lime or 0.5% Ma...
# Neem Coated Urea  : 435 | Single Superphosphate... Diammonium Phosphate (18-46-0): 109 | Neem Coat...  1 % Manganese sulphate + 0.25% lime or 0.5% Ma...
# Neem Coated Urea  : 435 | Single Superphosphate... Diammonium Phosphate (18-46-0): 109 | Neem Coat...  1 % Manganese sulphate + 0.25% lime or 0.5% Ma...
#
#                                                                                                                  Crop_Name
# Fertiliser_Combination_1                           Fertiliser_Combination_2
# Neem Coated Urea  : 0 | Single Superphosphate (... Diammonium Phosphate (18-46-0): 0 | Neem Coated...  Buck Wheat (Kaspat)
# Neem Coated Urea  : 217 | Single Superphosphate... Diammonium Phosphate (18-46-0): 43 | Neem Coate...              Mustard
# Neem Coated Urea  : 217 | Single Superphosphate... Diammonium Phosphate (18-46-0): 65 | Neem Coate...              Mustard
# Neem Coated Urea  : 217 | Single Superphosphate... Diammonium Phosphate (18-46-0): 87 | Neem Coate...              Mustard
# Neem Coated Urea  : 217 | Single Superphosphate... Diammonium Phosphate (18-46-0): 87 | Neem Coate...              Mustard
# ...                                                                                                                    ...
# Neem Coated Urea  : 435 | Single Superphosphate... Diammonium Phosphate (18-46-0): 87 | Neem Coate...               Cotton
# Neem Coated Urea  : 435 | Single Superphosphate... Diammonium Phosphate (18-46-0): 87 | Neem Coate...               Cotton
# Neem Coated Urea  : 435 | Single Superphosphate... Diammonium Phosphate (18-46-0): 87 | Neem Coate...               Cotton
# Neem Coated Urea  : 435 | Single Superphosphate... Diammonium Phosphate (18-46-0): 109 | Neem Coat...               Cotton
# Neem Coated Urea  : 435 | Single Superphosphate... Diammonium Phosphate (18-46-0): 109 | Neem Coat...               Cotton
#
# [72 rows x 5 columns]

# %%
dfinal.describe()
# Out:
#                      SampleNo      Parameters  \
# count                    5638            5638
# unique                    980               4
# top     PB/2017-18/95522227/1  Manganese (Mn)
# freq                       24            3716
#
#        Fertilizer_Recommendations_ThroughSoil  \
# count                                    5638
# unique                                      4
# top        Manganese sulphate (10 -25 kg/ha)
# freq                                     3716
#
#                   Fertilizer_Recommendations_ThroughSpray     Crop_Name  \
# count                                                5638          5638
# unique                                                  4             7
# top     1 % Manganese sulphate + 0.25% lime or 0.5% Ma...  Paddy(Dhaan)
# freq                                                 3716          1289
#
#                                  Fertiliser_Combination_1  \
# count                                                5638
# unique                                                 68
# top     Neem Coated Urea  : 0 | Single Superphosphate ...
# freq                                                 2273
#
#                                  Fertiliser_Combination_2
# count                                                5638
# unique                                                 72
# top     Diammonium Phosphate (18-46-0): 0 | Neem Coate...
# freq                                                 2273

# %%
dfinal.count()
# Out:
# SampleNo                                   5638
# Parameters                                 5638
# Fertilizer_Recommendations_ThroughSoil     5638
# Fertilizer_Recommendations_ThroughSpray    5638
# Crop_Name                                  5638
# Fertiliser_Combination_1                   5638
# Fertiliser_Combination_2                   5638
# dtype: int64

# %%
#plt.plot('Longitude','pH')
#data=data.astype(float)
#data.plot(x='Longitude', y='EC', style='o')
plt.plot(data['Longitude'], data['pH'])
plt.xlabel("Longitude")
plt.ylabel("pH")
plt.show()

# %%
plt.plot(data['Longitude'], data['EC (ds/m)'])
plt.show()

# %%
plt.plot(data['Longitude'], data['Organic Carbon (% L)'])
plt.show()

# %%
plt.scatter(data['Longitude'], data['Zinc Label'])
plt.xlabel("Longitude")
plt.ylabel("Zinc Label")
plt.show()

# %%
plt.bar(data['Longitude'], data['Sulphur label'])
# Out:
# <BarContainer object of 1415 artists>

# %%
plt.bar(data['Latitude'], data['Sulphur label'])
# Out:
# <BarContainer object of 1415 artists>

# %%
plt.scatter(data['Latitude'],data['Iron Label'])

# %%
plt.plot(data['Longitude'], data['pH'])
plt.plot(data['Longitude'], data['EC (ds/m)'])
plt.plot(data['Longitude'], data['Organic Carbon (% L)'])
plt.plot(data['Longitude'], data['Phosphorus (kg/ha)'])
plt.plot(data['Longitude'], data['Sulphur (ppm)'])
plt.plot(data['Longitude'], data['Iron(ppm)'])
plt.plot(data['Longitude'], data['Manganese (ppm)'])
plt.plot(data['Longitude'], data['Copper(ppm)'])


plt.legend(['pH', 'EC (ds/m)', 'Organic Carbon (% L)', 'Phosphorus (kg/ha)','Sulphur (ppm)','Iron(ppm)', 'Copper(ppm)'], loc='upper left')

# Add labels and title
plt.title("Interactive Plot")
plt.xlabel("Longitude")
plt.ylabel("Y-axis")
plt.figure(figsize=(8,9))

# %%
correlation_matrix = data.corr()
sns.heatmap(correlation_matrix, annot=True)
plt.figure(figsize = (20,20))
plt.show()

# %%
sns.heatmap(data.isnull())
plt.figure(figsize=(20, 8))
plt.show()

# %%
df2 = pd.read_csv('/Users/apple/Desktop/Documents/DataX-AgriAI-master/SHC_Data/SHC_Punjab_Amritsar_Ajnala_Fertilizers.csv')

# %%
sns.set(style="darkgrid")

# %%
#f = sns.load_dataset("SHC_Punjab_Amritsar_Ajnala_Basic.csv")
sns.relplot(x="Longitude", y="EC (ds/m)", hue="pH", data=data);

# %%
sns.relplot(x="Latitude", y="EC (ds/m)", hue="pH", data=data);

# %%
sns.catplot(x="Parameters",y="Crop_Name",data = dfinal)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-112-98da49a6264e> in <module>
# ----> 1 sns.catplot(x="Parameters",y="Crop_Name",data = dfinal)
#
# /Users/apple/opt/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py in catplot(x, y, hue, data, row, col, col_wrap, estimator, ci, n_boot, units, order, hue_order, row_order, col_order, kind, height, aspect, orient, color, palette, legend, legend_out, sharex, sharey, margin_titles, facet_kws, **kwargs)
#    3714     # facets to ensure representation of all data in the final plot
#    3715     p = _CategoricalPlotter()
# -> 3716     p.establish_variables(x_, y_, hue, data, orient, order, hue_order)
#    3717     order = p.group_names
#    3718     hue_order = p.hue_names
#
# /Users/apple/opt/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     156
#     157             # Figure out the plotting orientation
# --> 158             orient = self.infer_orient(x, y, orient)
#     159
#     160             # Option 2a:
#
# /Users/apple/opt/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py in infer_orient(self, x, y, orient)
#     359         elif is_not_numeric(y):
#     360             if is_not_numeric(x):
# --> 361                 raise ValueError(no_numeric)
#     362             else:
#     363                 return "h"
#
# ValueError: Neither the `x` nor `y` variable appears to be numeric.

# %%
dfinal.head()
# Out:
#                 SampleNo Parameters  \
# 0  PB/2017-18/95639425/2  Iron (Fe)
# 1  PB/2017-18/95639425/2  Iron (Fe)
# 2  PB/2017-18/95639425/2  Iron (Fe)
# 3  PB/2017-18/95639425/2  Iron (Fe)
# 4  PB/2017-18/95639425/2  Iron (Fe)
#
#               Fertilizer_Recommendations_ThroughSoil  \
# 0  Ferrous sulphate (25-50 kg/ha) (Soil applicati...
# 1  Ferrous sulphate (25-50 kg/ha) (Soil applicati...
# 2  Ferrous sulphate (25-50 kg/ha) (Soil applicati...
# 3  Ferrous sulphate (25-50 kg/ha) (Soil applicati...
# 4  Ferrous sulphate (25-50 kg/ha) (Soil applicati...
#
#             Fertilizer_Recommendations_ThroughSpray            Crop_Name  \
# 0  1%  Ferrous sulphate (Spray thrice)+ 0.5 % lime   Buck Wheat (Kaspat)
# 1  1%  Ferrous sulphate (Spray thrice)+ 0.5 % lime          Paddy(Dhaan)
# 2  1%  Ferrous sulphate (Spray thrice)+ 0.5 % lime                 Maize
# 3  1%  Ferrous sulphate (Spray thrice)+ 0.5 % lime               Mustard
# 4  1%  Ferrous sulphate (Spray thrice)+ 0.5 % lime             Sugarcane
#
#                             Fertiliser_Combination_1  \
# 0  Neem Coated Urea  : 0 | Single Superphosphate ...
# 1  Neem Coated Urea  : 0 | Single Superphosphate ...
# 2  Neem Coated Urea  : 361 | Single Superphosphat...
# 3  Neem Coated Urea  : 289 | Single Superphosphat...
# 4  Neem Coated Urea  : 0 | Single Superphosphate ...
#
#                             Fertiliser_Combination_2
# 0  Diammonium Phosphate (18-46-0): 0 | Neem Coate...
# 1  Diammonium Phosphate (18-46-0): 0 | Neem Coate...
# 2  Diammonium Phosphate (18-46-0): 130 | Neem Coa...
# 3  Diammonium Phosphate (18-46-0): 65 | Neem Coat...
# 4  Diammonium Phosphate (18-46-0): 0 | Neem Coate...

# %%
df  = dfinal.merge(data, on="SampleNo", how = 'inner')

# %%
df.head(5)
# Out:
#                 SampleNo Parameters  \
# 0  PB/2017-18/95639425/2  Iron (Fe)
# 1  PB/2017-18/95639425/2  Iron (Fe)
# 2  PB/2017-18/95639425/2  Iron (Fe)
# 3  PB/2017-18/95639425/2  Iron (Fe)
# 4  PB/2017-18/95639425/2  Iron (Fe)
#
#               Fertilizer_Recommendations_ThroughSoil  \
# 0  Ferrous sulphate (25-50 kg/ha) (Soil applicati...
# 1  Ferrous sulphate (25-50 kg/ha) (Soil applicati...
# 2  Ferrous sulphate (25-50 kg/ha) (Soil applicati...
# 3  Ferrous sulphate (25-50 kg/ha) (Soil applicati...
# 4  Ferrous sulphate (25-50 kg/ha) (Soil applicati...
#
#             Fertilizer_Recommendations_ThroughSpray            Crop_Name  \
# 0  1%  Ferrous sulphate (Spray thrice)+ 0.5 % lime   Buck Wheat (Kaspat)
# 1  1%  Ferrous sulphate (Spray thrice)+ 0.5 % lime          Paddy(Dhaan)
# 2  1%  Ferrous sulphate (Spray thrice)+ 0.5 % lime                 Maize
# 3  1%  Ferrous sulphate (Spray thrice)+ 0.5 % lime               Mustard
# 4  1%  Ferrous sulphate (Spray thrice)+ 0.5 % lime             Sugarcane
#
#                             Fertiliser_Combination_1  \
# 0  Neem Coated Urea  : 0 | Single Superphosphate ...
# 1  Neem Coated Urea  : 0 | Single Superphosphate ...
# 2  Neem Coated Urea  : 361 | Single Superphosphat...
# 3  Neem Coated Urea  : 289 | Single Superphosphat...
# 4  Neem Coated Urea  : 0 | Single Superphosphate ...
#
#                             Fertiliser_Combination_2  LandArea(Acre)  \
# 0  Diammonium Phosphate (18-46-0): 0 | Neem Coate...             3.0
# 1  Diammonium Phosphate (18-46-0): 0 | Neem Coate...             3.0
# 2  Diammonium Phosphate (18-46-0): 130 | Neem Coa...             3.0
# 3  Diammonium Phosphate (18-46-0): 65 | Neem Coat...             3.0
# 4  Diammonium Phosphate (18-46-0): 0 | Neem Coate...             3.0
#
#    Longitude  Latitude  ...  Sulphur (ppm)  Sulphur label  Zinc(ppm)  \
# 0  31.525681   74.4866  ...          65.32              S       1.62
# 1  31.525681   74.4866  ...          65.32              S       1.62
# 2  31.525681   74.4866  ...          65.32              S       1.62
# 3  31.525681   74.4866  ...          65.32              S       1.62
# 4  31.525681   74.4866  ...          65.32              S       1.62
#
#    Zinc Label Iron(ppm)  Iron Label Manganese (ppm)  Maganese Label  \
# 0           S      4.22           D            3.33               S
# 1           S      4.22           D            3.33               S
# 2           S      4.22           D            3.33               S
# 3           S      4.22           D            3.33               S
# 4           S      4.22           D            3.33               S
#
#   Copper(ppm)  copper Label
# 0        0.99             S
# 1        0.99             S
# 2        0.99             S
# 3        0.99             S
# 4        0.99             S
#
# [5 rows x 27 columns]

# %%
df.count()
# Out:
# SampleNo                                   5694
# Parameters                                 5694
# Fertilizer_Recommendations_ThroughSoil     5694
# Fertilizer_Recommendations_ThroughSpray    5694
# Crop_Name                                  5694
# Fertiliser_Combination_1                   5694
# Fertiliser_Combination_2                   5694
# LandArea(Acre)                             5686
# Longitude                                  5694
# Latitude                                   5694
# pH                                         5694
# EC (ds/m)                                  5694
# Organic Carbon (% L)                       5694
# Phosphorus (kg/ha)                         5694
# Phosphorus Label                           5694
# Potassium (kh/ha)                          5694
# Potessium Label                            5694
# Sulphur (ppm)                              5694
# Sulphur label                              5694
# Zinc(ppm)                                  5694
# Zinc Label                                 5694
# Iron(ppm)                                  5694
# Iron Label                                 5694
# Manganese (ppm)                            5694
# Maganese Label                             5684
# Copper(ppm)                                5694
# copper Label                               5694
# dtype: int64

# %%
pd.set_option('display.max_columns', 500)
df.head(5)
# Out:
#                 SampleNo Parameters  \
# 0  PB/2017-18/95639425/2  Iron (Fe)
# 1  PB/2017-18/95639425/2  Iron (Fe)
# 2  PB/2017-18/95639425/2  Iron (Fe)
# 3  PB/2017-18/95639425/2  Iron (Fe)
# 4  PB/2017-18/95639425/2  Iron (Fe)
#
#               Fertilizer_Recommendations_ThroughSoil  \
# 0  Ferrous sulphate (25-50 kg/ha) (Soil applicati...
# 1  Ferrous sulphate (25-50 kg/ha) (Soil applicati...
# 2  Ferrous sulphate (25-50 kg/ha) (Soil applicati...
# 3  Ferrous sulphate (25-50 kg/ha) (Soil applicati...
# 4  Ferrous sulphate (25-50 kg/ha) (Soil applicati...
#
#             Fertilizer_Recommendations_ThroughSpray            Crop_Name  \
# 0  1%  Ferrous sulphate (Spray thrice)+ 0.5 % lime   Buck Wheat (Kaspat)
# 1  1%  Ferrous sulphate (Spray thrice)+ 0.5 % lime          Paddy(Dhaan)
# 2  1%  Ferrous sulphate (Spray thrice)+ 0.5 % lime                 Maize
# 3  1%  Ferrous sulphate (Spray thrice)+ 0.5 % lime               Mustard
# 4  1%  Ferrous sulphate (Spray thrice)+ 0.5 % lime             Sugarcane
#
#                             Fertiliser_Combination_1  \
# 0  Neem Coated Urea  : 0 | Single Superphosphate ...
# 1  Neem Coated Urea  : 0 | Single Superphosphate ...
# 2  Neem Coated Urea  : 361 | Single Superphosphat...
# 3  Neem Coated Urea  : 289 | Single Superphosphat...
# 4  Neem Coated Urea  : 0 | Single Superphosphate ...
#
#                             Fertiliser_Combination_2  LandArea(Acre)  \
# 0  Diammonium Phosphate (18-46-0): 0 | Neem Coate...             3.0
# 1  Diammonium Phosphate (18-46-0): 0 | Neem Coate...             3.0
# 2  Diammonium Phosphate (18-46-0): 130 | Neem Coa...             3.0
# 3  Diammonium Phosphate (18-46-0): 65 | Neem Coat...             3.0
# 4  Diammonium Phosphate (18-46-0): 0 | Neem Coate...             3.0
#
#    Longitude  Latitude    pH  EC (ds/m)  Organic Carbon (% L)  \
# 0  31.525681   74.4866  7.85       0.25                  0.46
# 1  31.525681   74.4866  7.85       0.25                  0.46
# 2  31.525681   74.4866  7.85       0.25                  0.46
# 3  31.525681   74.4866  7.85       0.25                  0.46
# 4  31.525681   74.4866  7.85       0.25                  0.46
#
#    Phosphorus (kg/ha) Phosphorus Label  Potassium (kh/ha) Potessium Label  \
# 0               36.56                M             101.52               L
# 1               36.56                M             101.52               L
# 2               36.56                M             101.52               L
# 3               36.56                M             101.52               L
# 4               36.56                M             101.52               L
#
#    Sulphur (ppm) Sulphur label  Zinc(ppm) Zinc Label  Iron(ppm) Iron Label  \
# 0          65.32             S       1.62          S       4.22          D
# 1          65.32             S       1.62          S       4.22          D
# 2          65.32             S       1.62          S       4.22          D
# 3          65.32             S       1.62          S       4.22          D
# 4          65.32             S       1.62          S       4.22          D
#
#    Manganese (ppm) Maganese Label  Copper(ppm) copper Label
# 0             3.33              S         0.99            S
# 1             3.33              S         0.99            S
# 2             3.33              S         0.99            S
# 3             3.33              S         0.99            S
# 4             3.33              S         0.99            S

# %%
sns.catplot(x="Parameters",y="",data=df)

# %%
df.columns
# Out:
# Index(['SampleNo', 'Parameters', 'Fertilizer_Recommendations_ThroughSoil',
#        'Fertilizer_Recommendations_ThroughSpray', 'Crop_Name',
#        'Fertiliser_Combination_1', 'Fertiliser_Combination_2',
#        'LandArea(Acre)', 'Longitude', 'Latitude', 'pH', 'EC (ds/m)',
#        'Organic Carbon (% L)', 'Phosphorus (kg/ha)', 'Phosphorus Label',
#        'Potassium (kh/ha)', 'Potessium Label', 'Sulphur (ppm)',
#        'Sulphur label', 'Zinc(ppm)', 'Zinc Label', 'Iron(ppm)', 'Iron Label',
#        'Manganese (ppm)', 'Maganese Label', 'Copper(ppm)', 'copper Label'],
#       dtype='object')

# %%
sns.relplot(x="pH", y="Parameters", data=df);

# %%
sns.catplot(x="pH",y="Parameters",data=df)

# %%
sns.catplot(x="Latitude",y="Parameters",data=df)

# %%
sns.catplot(x="Longitude",y="Parameters",data=df)

# %%
correlation_matrix = df.corr()
plt.figure(figsize = (20,20))
sns.heatmap(correlation_matrix, annot=True)
plt.show()

# %%
plt.plot(data['Longitude'], data['Zinc(ppm)'])
plt.plot(data['Longitude'], data['Iron(ppm)'])
plt.xlabel("Longitude")
plt.ylabel("ppm")
plt.legend(['Zinc','Iron'])

# %%
plt.plot(data['Latitude'], data['Zinc(ppm)'])
plt.plot(data['Latitude'], data['Iron(ppm)'])
plt.xlabel("Longitude")
plt.ylabel("ppm")
plt.legend(['Zinc','Iron'])

# %%
sns.catplot(x="Parameters", y="EC (ds/m)", kind="box", data=df);

# %%
sns.catplot(x="Parameters", y="pH", kind="box", data=df);

# %%
 plt.bar('Latitude', 'Zinc Label')
plt.xlabel('Latitude')
plt.ylabel('Zinc')
# Out:
# Text(0,0.5,'Zinc')

# %%
sns.catplot(x="Latitude", y="pH", kind="box", data=df);

# %%
sns.catplot(x="Longitude", y="pH", kind="box", data=df);

# %%
plt.plot(data['Longitude'], data['Zinc(ppm)'])
plt.plot(data['Longitude'], data['Manganese (ppm)'])
plt.xlabel("Longitude")
plt.ylabel("ppm")
plt.legend(['Zinc','Mangnese'])
