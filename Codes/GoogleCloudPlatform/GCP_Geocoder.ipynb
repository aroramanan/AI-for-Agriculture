# %%
import pandas as pd

# %%
raw_data = pd.read_csv(r'C:\Users\Manan Arora\Desktop\Plaksha TLF\DataX Project\Agriculture\Datatsets\Daily-Market-Price-Data\DailyPrices_2019_Cleaned.csv')

# %%
raw_data.head()
# Out:
#        STATE          DISTRICT            MARKET     COMMODITY    VARIETY  \
# 0  Jharkhand            Ranchi            Khunti     Chili Red      Other
# 1  Meghalaya  Nongpoh (R-Bhoi)  Nongpoh (R-Bhoi)  Betal Leaves      Other
# 2  Meghalaya   West Garo Hills           Rongram  Betal Leaves      Local
# 3    Manipur           Chandel             Moreh     Masur Dal  Masur Dal
# 4    Manipur           Thoubal           Thoubal     Masur Dal  Masur Dal
#
#    ARRIVAL_DATE  MIN_PRICE  MAX_PRICE  MODAL_PRICE
# 0      20190228    17500.0    19500.0      18500.0
# 1      20190306    25000.0    30000.0      28000.0
# 2      20190503    10000.0    15000.0      12000.0
# 3      20190510        0.0     7400.0       7400.0
# 4      20190218        0.0     7500.0       7500.0

# %%
only_geo = raw_data[['STATE','DISTRICT','MARKET']]

# %%
only_geo.drop_duplicates(inplace = True)
# Out:
# C:\Users\Manan Arora\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
only_geo.shape
# Out:
# (2356, 3)

# %%
only_geo['ADDRESS']=only_geo['MARKET'].astype(str)+','+only_geo['DISTRICT']+','+only_geo['STATE']
# Out:
# C:\Users\Manan Arora\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
only_geo.head()
# Out:
#        STATE          DISTRICT            MARKET  \
# 0  Jharkhand            Ranchi            Khunti
# 1  Meghalaya  Nongpoh (R-Bhoi)  Nongpoh (R-Bhoi)
# 2  Meghalaya   West Garo Hills           Rongram
# 3    Manipur           Chandel             Moreh
# 4    Manipur           Thoubal           Thoubal
#
#                                        ADDRESS
# 0                      Khunti,Ranchi,Jharkhand
# 1  Nongpoh (R-Bhoi),Nongpoh (R-Bhoi),Meghalaya
# 2            Rongram,West Garo Hills,Meghalaya
# 3                        Moreh,Chandel,Manipur
# 4                      Thoubal,Thoubal,Manipur

# %%
locations = list(only_geo['ADDRESS'])
latitude = []
longitude = []
from geopy.geocoders import GoogleV3
geolocator = GoogleV3(api_key='AIzaSyDpW6-IyEZvR-nNBYP7uUv4v4kHjKxfI50')
for location in locations:
    print(location)
    results = geolocator.geocode(query=location, language='en', exactly_one=False, timeout=5)
    latitude+=[results[0][1][0]]
    longitude+=[results[0][1][1]]
# Out:
# Khunti,Ranchi,Jharkhand
# Nongpoh (R-Bhoi),Nongpoh (R-Bhoi),Meghalaya
# Rongram,West Garo Hills,Meghalaya
# Moreh,Chandel,Manipur
# Thoubal,Thoubal,Manipur
# Dimapur,Dimapur,Nagaland
# Wokha Town,Wokha,Nagaland
# Cuddapah,Cuddapah,Andhra Pradesh
# Duggirala,Guntur,Andhra Pradesh
# Bishenpur,Bishnupur,Manipur
# Imphal,Imphal West,Manipur
# Karaikal,Karaikal,Pondicherry
# Shillong,East Khasi Hills,Meghalaya
# Dadengiri,West Garo Hills,Meghalaya
# Lohardaga,Lohardaga,Jharkhand
# Kurnool,Kurnool,Andhra Pradesh
# Sohra,East Khasi Hills,Meghalaya
# Lamlong Bazaar,Imphal East,Manipur
# Laskein,West Jaintia Hills,Meghalaya
# Thattanchavady,Pondicherry,Pondicherry
# Mawiong Regulated Market,East Khasi Hills,Meghalaya
# Tura,West Garo Hills,Meghalaya
# Kohima,Kohima,Nagaland
# Guntur,Guntur,Andhra Pradesh
# Canacona,South Goa,Goa
# Khliehriat,East Jaintia Hills,Meghalaya
# Jowai,West Jaintia Hills,Meghalaya
# Port Blair,South Andaman,Andaman and Nicobar
# Giridih,Giridih,Jharkhand
# ...

# %%
only_geo['LATITUDE'] = latitude
only_geo['LONGITUDE'] = longitude
# Out:
# C:\Users\Manan Arora\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\Manan Arora\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
only_geo.head()
# Out:
#        STATE          DISTRICT            MARKET  \
# 0  Jharkhand            Ranchi            Khunti
# 1  Meghalaya  Nongpoh (R-Bhoi)  Nongpoh (R-Bhoi)
# 2  Meghalaya   West Garo Hills           Rongram
# 3    Manipur           Chandel             Moreh
# 4    Manipur           Thoubal           Thoubal
#
#                                        ADDRESS   LATITUDE  LONGITUDE
# 0                      Khunti,Ranchi,Jharkhand  23.079760  85.277421
# 1  Nongpoh (R-Bhoi),Nongpoh (R-Bhoi),Meghalaya  25.869914  91.833721
# 2            Rongram,West Garo Hills,Meghalaya  25.594539  90.250270
# 3                        Moreh,Chandel,Manipur  24.251281  94.301304
# 4                      Thoubal,Thoubal,Manipur  24.644924  93.999290

# %%
raw_data.head()
# Out:
#        STATE          DISTRICT            MARKET     COMMODITY    VARIETY  \
# 0  Jharkhand            Ranchi            Khunti     Chili Red      Other
# 1  Meghalaya  Nongpoh (R-Bhoi)  Nongpoh (R-Bhoi)  Betal Leaves      Other
# 2  Meghalaya   West Garo Hills           Rongram  Betal Leaves      Local
# 3    Manipur           Chandel             Moreh     Masur Dal  Masur Dal
# 4    Manipur           Thoubal           Thoubal     Masur Dal  Masur Dal
#
#    ARRIVAL_DATE  MIN_PRICE  MAX_PRICE  MODAL_PRICE  \
# 0      20190228    17500.0    19500.0      18500.0
# 1      20190306    25000.0    30000.0      28000.0
# 2      20190503    10000.0    15000.0      12000.0
# 3      20190510        0.0     7400.0       7400.0
# 4      20190218        0.0     7500.0       7500.0
#
#                                        ADDRESS
# 0                      Khunti,Ranchi,Jharkhand
# 1  Nongpoh (R-Bhoi),Nongpoh (R-Bhoi),Meghalaya
# 2            Rongram,West Garo Hills,Meghalaya
# ...

# %%
raw_data['ADDRESS']=raw_data['MARKET'].astype(str)+','+raw_data['DISTRICT']+','+raw_data['STATE']
full_data = raw_data.merge(only_geo[['ADDRESS','LATITUDE','LONGITUDE']],on='ADDRESS')

# %%
full_data.to_csv(r'C:\Users\Manan Arora\Desktop\Plaksha TLF\DataX Project\Agriculture\Datatsets\DailyPrices_2019_withLatLong.csv')

# %%
only_geo[['ADDRESS','LATITUDE','LONGITUDE']].to_csv(r'C:\Users\Manan Arora\Desktop\Plaksha TLF\DataX Project\Agriculture\Datatsets\MarketsList_2019_LatLong.csv', index = False)

# %%
raw_data[['COMMODITY','VARIETY']].drop_duplicates().to_csv(r'C:\Users\Manan Arora\Desktop\Plaksha TLF\DataX Project\Agriculture\Datatsets\CommodityNamesList.csv',index = False)

# %%
raw_data[['COMMODITY','VARIETY']].drop_duplicates().shape
# Out:
# (655, 2)
